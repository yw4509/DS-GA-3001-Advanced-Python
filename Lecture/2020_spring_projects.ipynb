# %% [markdown]
# # 2020 Spring; Advanced Python for Data Science; Projects
#
# Students within a group will develop a problem that they would like to work on. After "project proposal presentations" the instructor will schedule and meet with groups whose proposals are either overly or insufficiently complex.
#
#
# The proposal and final project will be graded based on:
#
# - Demonstrated understanding of advanced Python concepts
#
# - Demonstrated understanding of the final project problem
#
# - Quality of documentation: one report of maximum 4 pages; for final project only
#
# - Quality of the presentation: clarity of the exposition, slides quality, and duration (the groups should respect the time slot, 5 minutes with extra 1-2 minutes for questions).

# %% [markdown]
# ## Projects Examples:

# %% [markdown]
# - Optimization tools; such as fast numerical computation; or mathematical models
# and tools for data science;
#
#
# - Social Network Analysis;
#
#
# - Twitter analysis;
#
#
# - Dynamical Processes: epidemics, market adoption, etc.;
#
#
# - Neural network projects optimized;
#
#
# - Processing and/or statistics of "large objects": e.g. fast or memory efficient algorithm on: images, data sets, data streams;
#
#
# - NYC Taxi fare prediction:
# https://www.kaggle.com/c/new-york-city-taxi-fare-prediction/data
#
#
# - Stock Portfolio Optimization;
#
#
# - Efficient forecasting over large data sets or streams;
#
#
# - Stochastic models for predictions of: road/train-system delays;
# product adoption; spread of epidemics;
#
#
# - Improvement of some of your previous machine learning projects by using the tools from
# "Advanced Data Science" course;
#
#
# - etc.

# %% [markdown]
# # Groups and Students
#
# The students in the class will form groups of 5 students on their own.

# %% [markdown]
# ---
# ### Group 01
#
# Micaela Flores: mrf444@nyu.edu
# Kelly Sooch: kas1080@nyu.edu
# Sheetal Laad: sl7054@nyu.edu
# Ziv Schwartz: zs1349@nyu.edu
# Orion Taylor: ojt212@nyu.edu
#
#
# ---
# ### Group 02
#
# Bolin Yang: by641@nyu.edu
# Yucheng Xin: yx1069@nyu.edu
# Yaner He: yh2278@nyu.edu
# Yadi Deng: yd881@nyu.edu
# Anqi Zhang: az983@nyu.edu
# Chengwei Chen: cc6576@nyu.edu
#
# ---
# ### Group 03
#
# Yuqi Dai: yd735@nyu.edu
# Zihao Zhao:zz913@nyu.edu
# Xin Wu: xw1039@nyu.edu
# Zhewen Song: zs1356@nyu.edu
# Haonan Tian: ht1151@nyu.edu
#
# ---
# ### Group 04
#
# Tinatin Nikvashvili: tn709@nyu.edu
# Paula Kiatkamolwong: kk4158@nyu.edu
# Khasi-Marc Jamieson: kmj426@nyu.edu
# Will Egan: wve204@nyu.edu
# Nathan Levi Griffin: nlg297@nyu.edu
# Anu-Ujin Gerelt-Od: ago265@nyu.edu
#
# ---
# ### Group 05
#
# Brina Seidel: bs3743@nyu.edu
# Ben Stadnick: brs426@nyu.edu
# Ross Bernstein: rb2540@nyu.edu
# Sree Govindaprasad: sg5715@nyu.edu
# Vishwaesh Rajiv: vr1059@nyu.edu
#
# ---
# ### Group 06
#
# Shirley Xu: xx852@nyu.edu
# Enyi Lian: el2986@nyu.edu
# Nimi Wang: nw1212@nyu.edu
# Zihao Guo: zg866@nyu.edu
# Ruoyu Zhu: rz1403@nyu.edu
#
#
#
# ---
# ### Group 07
#
#
# Wenting Qi: wq244@nyu.edu
# Rui Jiang: rj1407@nyu.edu
# Kaitai Zhang: kz1179@nyu.edu
# Yucong Hu: yh2860@nyu.edu
# Jiayi Du: jd4138@nyu.edu
# Eva Wang: sw2860@nyu.edu
#
#
# ---
# ### Group 08
#
# Yunya Wang: yw4509@nyu.edu
# Mingdi Zheng: mz2698@nyu.edu
# Cheng Zeng: cz1951@nyu.edu
# Ziyue Dong: zd780@nyu.edu
# Kanshuai Wang: kw2602@nyu.edu
#
#
# ---
# ### Group 09
#
# Kevin Wilson: ksw366@nyu.edu
# Aidan Claffey: adc501@nyu.edu
# Darren Geng: dg2458@nyu.edu
# Charles Brillo-Sonnino: cbs488@nyu.edu
# Meenakshi Gaurishankar Jhalani: mgj265@nyu.edu
#
# ---
# ### Group 10
#
# Siddesh Ramesh: sr3582@nyu.edu
# Shunran(Allen) Zhang: sz1383@nyu.edu
# Mark Estudillo: mje341@nyu.edu
# Dieter Erben: dev241@nyu.edu
# Bing Zou: bz1031@nyu.edu
# Liangzhi (Amber) Li: ll3399@nyu.edu
#
# ---
# ### Group 11
#
#
# ---
# ### Group 12
